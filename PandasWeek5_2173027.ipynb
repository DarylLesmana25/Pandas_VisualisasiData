# %% [markdown]
# <a href="https://colab.research.google.com/github/DarylLesmana25/Pandas_2173027_VisualisasiData/blob/main/PandasWeek5_2173027.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas 05**

# %% [markdown]
# # **#17 Resampling pada Data Deret Waktu (time series data)**
# Source : [Indonesia Belajar](https://youtu.be/zYcQgmzcHRM)

# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# # Persiapan Data Frame
# - Baris pada data frame kali ini bernilai jumlah hari dikali jam dalam sehari.
# - Berisi deret waktu dengan frekuensi per hour.

# %%
n_rows = 365 * 24
n_cols = 2
cols = ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)),
                  columns=cols)

df.index = pd.util.testing.makeDateIndex(n_rows, freq='H')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                      col1  col2
# 2000-01-01 00:00:00     6    17
# 2000-01-01 01:00:00    16    15
# 2000-01-01 02:00:00     8     3
# 2000-01-01 03:00:00    11    16
# 2000-01-01 04:00:00     4    15
# ...                   ...   ...
# 2000-12-30 19:00:00    18    10
# 2000-12-30 20:00:00     7    16
# 2000-12-30 21:00:00     8     1
# 2000-12-30 22:00:00     3    11
# 2000-12-30 23:00:00    15    10
#
# [8760 rows x 2 columns]

# %% [markdown]
# # Resampling Data dengan Interval Monthly
# - Resampling di dalam time series, bisa diartikan sebagai pengelompokkkan ulang data berdasarkan interval waktu tertentu.
# - Dengan menyertakan parameter M dalam fungsi resample(), kita bisa mengubah hourly based jadi monthly based.
# - Data yang sudah di resample tidak bisa diakses per-individual ulang, tetapi data yang bisa kita akses adalah data agregasi.
# - Data agregasi yang dimaksud adalah data yang sudah dikenakan fungsi sum()

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-31  7265
# 2000-02-29  7094
# 2000-03-31  7331
# 2000-04-30  7233
# 2000-05-31  7405
# 2000-06-30  7170
# 2000-07-31  7322
# 2000-08-31  7668
# 2000-09-30  7327
# 2000-10-31  7409
# 2000-11-30  7296
# 2000-12-31  7203

# %% [markdown]
# # Resampling Data dengan Interval Daily
# - Dengan menggunakan parameter D dalam fungsi resample(), kita bisa mengubah monthly based jadi daily based.

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-01   208
# 2000-01-02   255
# 2000-01-03   256
# 2000-01-04   232
# 2000-01-05   246
# ...          ...
# 2000-12-26   254
# 2000-12-27   298
# 2000-12-28   242
# 2000-12-29   256
# 2000-12-30   170
#
# [365 rows x 1 columns]

# %% [markdown]
# # **#18 Membentuk dummy Data Frame**
# Source : [Indonesia Belajar](https://youtu.be/JpvfG6in548)

# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np

#Cek versi
print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# # Membentuk Data Frame dari Dictionary
# - Menggunakan dictionary. Dimana keys akan menjadi nama kolom dan value akan menjadi nilai dari kolom.

# %%
pd.DataFrame({'col1':[1, 2, 3, 4], 
              'col2':[5, 6, 7, 8]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %% [markdown]
# # Membentuk Data Frame dari Numpy Array
# - Pertama tentukan jumlah baris dan kolom.
# - Generate random integer untuk baris dan kolom tersebut.
# - Simpan kedalam suatu variabel.
# - Masukkan kedalam dataframe.
# - Karena numpy array tidak memiliki nama label, pada kasus kali ini kita menggunakan fungsi tuple untuk nama tabel.

# %%
n_rows = 5
n_cols = 3

arr = np.random.randint(1, 20, size=(n_rows, n_cols))
arr
# Out:
# array([[18, 19, 14],
#        [16, 10,  9],
#        [ 3, 12,  9],
#        [ 3,  1, 13],
#        [ 5,  1, 13]])

# %%
pd.DataFrame(arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0  18  19  14
# 1  16  10   9
# 2   3  12   9
# 3   3   1  13
# 4   5   1  13

# %% [markdown]
# # Membentuk Data Frame dengan Memanfaatkan pandas.util.testing
# 1. Membuat dummy dataframe

# %%
pd.util.testing.makeDataFrame().head()
# Out:
#                    A         B         C         D
# FdVnJyEupu -1.207838 -0.937369  0.570853 -0.761103
# 9hybWRcbGf -3.643616  1.460236  0.889200 -0.301969
# aer0S44XBT  0.969852  0.855671  1.005951  0.435833
# XGUW4ecNhR -0.388958 -1.615785  0.308396  0.587779
# bzWeMOCWoD  0.946565  0.090228  1.224827 -0.569235

# %% [markdown]
# 2. Membuat dummy dataframe dengan tipe data yang berbeda

# %%
pd.util.testing.makeMixedDataFrame().head()
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %% [markdown]
# 3. Membuat dummy dataframe yang berisi time series data

# %%
pd.util.testing.makeTimeDataFrame().head()
# Out:
#                    A         B         C         D
# 2000-01-03 -0.293241 -1.281909  1.879423 -1.230204
# 2000-01-04 -0.203470  0.225887  1.758526  1.964581
# 2000-01-05  0.650299 -0.788070 -0.633825 -0.469955
# 2000-01-06 -0.526066  0.564564  1.176361 -1.619619
# 2000-01-07 -0.826245 -0.487781  0.094149 -0.612630

# %% [markdown]
# 4. Membuat dummy dataframe dengan beberapa missing value yang ditempatkan secara acak

# %%
pd.util.testing.makeMissingDataframe().head()
# Out:
#                    A         B         C         D
# 0rMVLSbkwX -0.217528 -1.359814 -0.203725  1.806426
# QQqiTc1aR5  0.501043 -0.337803 -0.806233 -0.680910
# bG9CxZWNy9 -1.252493  1.018720 -0.143290  2.334829
# 5UsoJ4MRmz -1.045615  0.503806 -0.269693 -0.394179
# yv4vyscpf5 -0.486724 -1.438151  0.883196  0.630613

# %% [markdown]
# # **#19 Formatting tampilan Data Frame**
# Source : [Indonesia Belajar](https://youtu.be/ySKDbYXFN2M)

# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.5
# 1.21.6

# %% [markdown]
# # Persiapan Data Frame

# %%
n_rows = 5
n_cols = 2
cols = ['omset', 'operasional']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    omset  operasional
# 0      2            7
# 1      5           11
# 2     18           17
# 3     12           12
# 4     19            7

# %% [markdown]
# - Konversi omset dan operasional menjadi rupiah.
# - Underscore dalam python tidak akan membuat bilangan menjadi error, itu hanya digunakan untuk membantu membaca bilangan.

# %%
df['omset'] = df['omset'] * 100_000
df['operasional'] = df['operasional'] * 10_000
df
# Out:
#      omset  operasional
# 0   200000        70000
# 1   500000       110000
# 2  1800000       170000
# 3  1200000       120000
# 4  1900000        70000

# %% [markdown]
# - Membuat kolom tanggal
# - Diisi dengan menggunakan fungsi generate dengan frequensi daily based.

# %%
df.index = pd.util.testing.makeDateIndex(n_rows, freq='D')
df = df.reset_index()
df = df.rename(columns={'index':'tanggal'})
df
# Out:
#      tanggal    omset  operasional
# 0 2000-01-01   200000        70000
# 1 2000-01-02   500000       110000
# 2 2000-01-03  1800000       170000
# 3 2000-01-04  1200000       120000
# 4 2000-01-05  1900000        70000

# %% [markdown]
# # Melakukan formatting tampilan Data Frame
# - Gunakan dictionary dan tampung kedalam variabel.
# - Untuk setiap key disesuaikan dengan nama kolomnya, tetapi urutannya bebas.
# - Formatting menggunakan tipe data string.
# - :.2f digunakan untuk menyertakan 2 digit exstra di belakang koma.

# %%
formatku = {'tanggal':'{:%d/%m/%y}', 
            'operasional':'Rp {:.2f}',
            'omset':'Rp {:.2f}'}

laporan = df.style.format(formatku)
laporan # laporan bukan objek dataframe
# Out:
# <style type="text/css">
# </style>
# <table id="T_25124_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25124_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25124_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_25124_row0_col1" class="data row0 col1" >Rp 200000.00</td>
#       <td id="T_25124_row0_col2" class="data row0 col2" >Rp 70000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25124_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25124_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_25124_row1_col1" class="data row1 col1" >Rp 500000.00</td>
#       <td id="T_25124_row1_col2" class="data row1 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25124_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25124_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_25124_row2_col1" class="data row2 col1" >Rp 1800000.00</td>
#       <td id="T_25124_row2_col2" class="data row2 col2" >Rp 170000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25124_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25124_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_25124_row3_col1" class="data row3 col1" >Rp 1200000.00</td>
#       <td id="T_25124_row3_col2" class="data row3 col2" >Rp 120000.00</td>
#     </tr>
#     <tr>
#       <th id="T_25124_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25124_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_25124_row4_col1" class="data row4 col1" >Rp 1900000.00</td>
#       <td id="T_25124_row4_col2" class="data row4 col2" >Rp 70000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Variabel laporan bukan objek dataframe
# - Objek dataframe tetaplah df

# %%
type(laporan)
# Out:
# pandas.io.formats.style.Styler

# %% [markdown]
# Menghilangkan index (0, 1, ...).

# %%
laporan.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_25124_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25124_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_25124_row0_col1" class="data row0 col1" >Rp 200000.00</td>
#       <td id="T_25124_row0_col2" class="data row0 col2" >Rp 70000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_25124_row1_col1" class="data row1 col1" >Rp 500000.00</td>
#       <td id="T_25124_row1_col2" class="data row1 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_25124_row2_col1" class="data row2 col1" >Rp 1800000.00</td>
#       <td id="T_25124_row2_col2" class="data row2 col2" >Rp 170000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_25124_row3_col1" class="data row3 col1" >Rp 1200000.00</td>
#       <td id="T_25124_row3_col2" class="data row3 col2" >Rp 120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_25124_row4_col1" class="data row4 col1" >Rp 1900000.00</td>
#       <td id="T_25124_row4_col2" class="data row4 col2" >Rp 70000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Memberi keterangan

# %%
laporan.set_caption('Data Omset dan Operasional')
# Out:
# <style type="text/css">
# </style>
# <table id="T_25124_" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25124_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_25124_row0_col1" class="data row0 col1" >Rp 200000.00</td>
#       <td id="T_25124_row0_col2" class="data row0 col2" >Rp 70000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_25124_row1_col1" class="data row1 col1" >Rp 500000.00</td>
#       <td id="T_25124_row1_col2" class="data row1 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_25124_row2_col1" class="data row2 col1" >Rp 1800000.00</td>
#       <td id="T_25124_row2_col2" class="data row2 col2" >Rp 170000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_25124_row3_col1" class="data row3 col1" >Rp 1200000.00</td>
#       <td id="T_25124_row3_col2" class="data row3 col2" >Rp 120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_25124_row4_col1" class="data row4 col1" >Rp 1900000.00</td>
#       <td id="T_25124_row4_col2" class="data row4 col2" >Rp 70000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Memberi penanda warna pada dataframe

# %%
laporan.highlight_min('omset', color='pink')
laporan.highlight_max('omset', color='lightgreen')

laporan.highlight_min('operasional', color='lightblue')
laporan.highlight_max('operasional', color='grey')
# Out:
# <style type="text/css">
# #T_25124_row0_col1 {
#   background-color: pink;
# }
# #T_25124_row0_col2, #T_25124_row4_col2 {
#   background-color: lightblue;
# }
# #T_25124_row2_col2 {
#   background-color: grey;
# }
# #T_25124_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_25124_" class="dataframe">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >omset</th>
#       <th class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25124_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_25124_row0_col1" class="data row0 col1" >Rp 200000.00</td>
#       <td id="T_25124_row0_col2" class="data row0 col2" >Rp 70000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_25124_row1_col1" class="data row1 col1" >Rp 500000.00</td>
#       <td id="T_25124_row1_col2" class="data row1 col2" >Rp 110000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_25124_row2_col1" class="data row2 col1" >Rp 1800000.00</td>
#       <td id="T_25124_row2_col2" class="data row2 col2" >Rp 170000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_25124_row3_col1" class="data row3 col1" >Rp 1200000.00</td>
#       <td id="T_25124_row3_col2" class="data row3 col2" >Rp 120000.00</td>
#     </tr>
#     <tr>
#       <td id="T_25124_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_25124_row4_col1" class="data row4 col1" >Rp 1900000.00</td>
#       <td id="T_25124_row4_col2" class="data row4 col2" >Rp 70000.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **#20 Menggabungkan (merge) Dua Data Frame Secara Berdampingan**
# Source : [Indonesia Belajar](https://youtu.be/AldqObRhkDU)

# %% [markdown]
# # Import Modules

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 1.3.5

# %% [markdown]
# - Membuat 2 buah dataframe
# - Masing-masing dataframe akan memiliki dua buah dictionary

# %%
d1 = {'col1':[1, 2, 3], 
      'col2':[10, 20, 30]}
df1 = pd.DataFrame(d1)
df1
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30

# %%
d2 = {'col3':[4, 5, 6], 
      'col4':[40, 50, 60]}
df2 = pd.DataFrame(d2)
df2
# Out:
#    col3  col4
# 0     4    40
# 1     5    50
# 2     6    60

# %% [markdown]
# - Berbeda dengan trick sebelumnya, Kali ini hanya perlu menambahkan arguments True pada parameter left_index dan right_index.

# %%
df = pd.merge(df1, df2, left_index=True, right_index=True)
df
# Out:
#    col1  col2  col3  col4
# 0     1    10     4    40
# 1     2    20     5    50
# 2     3    30     6    60
